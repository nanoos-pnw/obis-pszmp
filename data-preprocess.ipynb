# %% [markdown]
# # Data pre-processing. PSZMP
#
# PSZMP dataset.
#
# 2/9,6,4, 1/31/2024

# %%
from datetime import datetime, timedelta, timezone
import json
from pathlib import Path

import numpy as np
import pandas as pd
import geopandas as gpd

from data_preprocess import read_and_parse_sourcedata

# %% [markdown]
# ## Read the data

# %%
data_pth = Path(".")

# %% [markdown]
# Set to `True` when debugging. `csv` ﬁles will not be exported when `debug_no_csvexport = True`

# %%
debug_no_csvexport = False

# %% [markdown]
# ## Process JSON file containing common mappings and strings

# %%
with open(data_pth / 'common_mappings.json') as f:
    common_mappings = json.load(f)

# %%
DatasetCode = common_mappings['datasetcode']
cruises = common_mappings['cruises']
stations = common_mappings['stations']
net_tow = common_mappings['net_tow']

iso8601_format = common_mappings['iso8601_format']
CRS = common_mappings['CRS']

# %% [markdown]
# ## Pre-process data from csv for Event table

# %% [markdown]
# ### Read the pre-processed csv file

# %% [markdown]
# `usecols` defines the columns that will be kept and the order in which they'll be organized

# %%
# From the Hood Canal dataset
# usecols = [
#     'sample_code', 'mesh_size', 'FWC_DS', 
#     'station', 'latitude', 'longitude', 
#     'date', 'time_start', 'time', 'day_night', 
#     'depth_min', 'depth_max',
#     'net_code', 'extra_sample_token'
# ]

usecols = [
    'Sample Code', 
    'Station', 'Latitude', 'Longitude', 'Site Name', 'Basin', 'Sampling Group',
    'Sample Date', 'Sample Time', 'Day_Night', 'time',
    'Min Tow Depth (m)', 'Max Tow Depth (m)', 'Station Depth (m)',
    'Mesh Size', 'Tow Type', 
]

# eventsource_df = read_and_parse_sourcedata(test_n_rows=1000)[usecols]
eventsource_df = read_and_parse_sourcedata()[usecols]

# TODO: Rename more columns, if needed
eventsource_df.rename(
    columns={
        'Sample Code':'sample_code',
        'Station':'station',
        'Latitude':'latitude',
        'Longitude':'longitude',
        'Min Tow Depth (m)':'depth_min', 
        'Max Tow Depth (m)':'depth_max', 
        'Mesh Size': 'mesh_size',
    },
    inplace=True
)

# %%
len(eventsource_df)
# Out:
# 153825

# %%
eventsource_df.head()
# Out:
#       sample_code station  latitude  longitude     Site Name           Basin  \
# 0  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 1  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 2  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 3  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 4  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
#
#   Sampling Group          Sample Date Sample Time Day_Night  \
# 0            LUM  2018-01-02 00:00:00    11:51:00         D
# 1            LUM  2018-01-02 00:00:00    11:51:00         D
# 2            LUM  2018-01-02 00:00:00    11:51:00         D
# 3            LUM  2018-01-02 00:00:00    11:51:00         D
# 4            LUM  2018-01-02 00:00:00    11:51:00         D
#
#                        time  depth_min  depth_max  Station Depth (m)  \
# 0 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 1 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 2 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 3 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 4 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
#
#    mesh_size  Tow Type
# 0        200  Vertical
# 1        200  Vertical
# 2        200  Vertical
# 3        200  Vertical
# 4        200  Vertical

# %% [markdown]
# ### Remove duplicates
#
# Will return only unique samples, where one row = one sample.

# %%
eventsource_df = eventsource_df.drop_duplicates().sort_values(by='sample_code').reset_index(drop=True)

# %%
len(eventsource_df)
# Out:
# 3567

# %% [markdown]
# - There are 51 unique stations
# - Adding 'Tow Type' didn't lead to duplication of stations. ie, each station has only one tow type.
# - Adding 'Station Depth (m)' did lead to huge duplication
# - Darn, adding 'Sampling Group' led to some duplication (60 records instead of 51). ie, some stations were visited by more than one 'Sampling Group'

# %%
stations_cols = ['station', 'latitude', 'longitude', 'Site Name', 'Basin', 'Sampling Group', 'Tow Type']

# %%
stations_unique_df = eventsource_df[stations_cols].drop_duplicates().sort_values(by='station').reset_index(drop=True)

# %%
len(stations_unique_df)
# Out:
# 60

# %%
sorted(stations_unique_df['Sampling Group'].unique())
# Out:
# ['HCSEG/DOE',
#  'KC',
#  'KWT',
#  'LUM',
#  'NIT',
#  'NOAA',
#  'NOAA/STIL',
#  'P Stations',
#  'PGST/WDFW',
#  'TUL']

# %%
stations_unique_df['Sampling Group'].value_counts()
# Out:
# NIT           10
# PGST/WDFW      8
# TUL            8
# KWT            8
# NOAA           6
# KC             6
# NOAA/STIL      5
# LUM            4
# P Stations     3
# HCSEG/DOE      2
# Name: Sampling Group, dtype: int64

# %%
stations_unique_df.head(60)
# Out:
#     station  latitude  longitude                Site Name            Basin  \
# 0      ADID  48.00274  -122.6374          Admiralty Inlet  Admiralty Inlet
# 1      ADIM  47.99915  -122.6664          Admiralty Inlet  Admiralty Inlet
# 2      ADIS  47.99063  -122.6872          Admiralty Inlet  Admiralty Inlet
# 3      ADIV  48.00273  -122.6360          Admiralty Inlet  Admiralty Inlet
# 4      CAMD  48.06646  -122.3956              Camano Head    Whidbey Basin
# 5      CAMM  48.06536  -122.3905              Camano Head    Whidbey Basin
# 6      CAMS  48.06469  -122.3886              Camano Head    Whidbey Basin
# 7      CAMV  48.05901  -122.3873              Camano Head    Whidbey Basin
# 8     COW1S  48.68448  -123.0400                  Cowlitz         San Juan
# 9     COW2D  48.68303  -123.0412                  Cowlitz         San Juan
# 10   COW2D2  48.67437  -123.0481                  Cowlitz         San Juan
# 11   COW3V2  48.67437  -123.0481                  Cowlitz         San Juan
# 12    DANAD  47.17997  -122.8318             Dana Passage      South Sound
# 13    DANAM  47.17678  -122.8352             Dana Passage      South Sound
# 14    DANAS  47.17593  -122.8355             Dana Passage      South Sound
# 15    DANAV  47.18327  -122.8307             Dana Passage      South Sound
# 16     ELID  48.63368  -122.5890             Eliza Island   Bellingham Bay
# 17     ELIM  48.64060  -122.5896             Eliza Island   Bellingham Bay
# 18     ELIS  48.64352  -122.5886             Eliza Island   Bellingham Bay
# 19     ELIV  48.63795  -122.5694             Eliza Island   Bellingham Bay
# 20  HCB003V  47.53787  -123.0096                    Eldon       Hood Canal
# 21  HCB003V  47.53787  -123.0096                    Eldon       Hood Canal
# 22  HCB004V  47.35620  -123.0249            Sisters Point       Hood Canal
# 23  HCB004V  47.35620  -123.0249            Sisters Point       Hood Canal
# 24    HOPED  48.41155  -122.5657        North Hope Island    Whidbey Basin
# 25    HOPED  48.41155  -122.5657        North Hope Island    Whidbey Basin
# 26    HOPES  48.40463  -122.5560        North Hope Island    Whidbey Basin
# 27    HOPEV  48.40622  -122.5783        North Hope Island    Whidbey Basin
# 28    HOPEV  48.40622  -122.5783        North Hope Island    Whidbey Basin
# 29  KSBP01D  47.74396  -122.4282          Point Jefferson    Central Basin
# 30  KSBP01V  47.74396  -122.4282          Point Jefferson    Central Basin
# 31  LSNT01D  47.53333  -122.4333           Point Williams    Central Basin
# 32  LSNT01S  47.54225  -122.4012           Point Williams    Central Basin
# 33  LSNT01V  47.53333  -122.4333           Point Williams    Central Basin
# 34     MUKD  47.95922  -122.2906                 Mukilteo    Whidbey Basin
# 35     MUKM  47.95711  -122.2873                 Mukilteo    Whidbey Basin
# 36     MUKS  47.95509  -122.2874                 Mukilteo    Whidbey Basin
# 37     MUKV  47.97166  -122.3222                 Mukilteo    Whidbey Basin
# 38  NSEX01V  47.35862  -122.3871             East Passage    Central Basin
# 39    SARAD  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 40    SARAD  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 41    SARAD  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 42    SARAS  48.27363  -122.5529   North Saratoga Passage    Whidbey Basin
# 43    SARAS  48.27363  -122.5529   North Saratoga Passage    Whidbey Basin
# 44    SARAV  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 45    SARAV  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 46    SARAV  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 47    SKETD  47.14032  -122.6377  South Ketron/Solo Point      South Sound
# 48   SKETD2  47.13932  -122.6490  South Ketron/Solo Point      South Sound
# 49    SKETM  47.13892  -122.6367  South Ketron/Solo Point      South Sound
# 50    SKETS  47.13843  -122.6354  South Ketron/Solo Point      South Sound
# 51    SKETV  47.15243  -122.6586  South Ketron/Solo Point      South Sound
# 52     TDBD  47.78343  -122.7334            Thorndyke Bay       Hood Canal
# 53     TDBM  47.79400  -122.7348            Thorndyke Bay       Hood Canal
# 54     TDBS  47.79868  -122.7334            Thorndyke Bay       Hood Canal
# 55     TDBV  47.78297  -122.7330            Thorndyke Bay       Hood Canal
# 56    WAT1S  48.43457  -122.8037             Watmough Bay         San Juan
# 57    WAT1V  48.43457  -122.8037             Watmough Bay         San Juan
# 58    WAT2D  48.43699  -122.7961             Watmough Bay         San Juan
# 59    WAT3V  48.43548  -122.7929             Watmough Bay         San Juan
#
#    Sampling Group  Tow Type
# 0       PGST/WDFW   Oblique
# 1       PGST/WDFW   Oblique
# 2       PGST/WDFW   Oblique
# 3       PGST/WDFW  Vertical
# 4             TUL   Oblique
# 5             TUL   Oblique
# 6             TUL   Oblique
# 7             TUL  Vertical
# 8             KWT   Oblique
# 9             KWT   Oblique
# 10            KWT   Oblique
# 11            KWT  Vertical
# 12            NIT   Oblique
# 13            NIT   Oblique
# 14            NIT   Oblique
# 15            NIT  Vertical
# 16            LUM   Oblique
# 17            LUM   Oblique
# 18            LUM   Oblique
# 19            LUM  Vertical
# 20     P Stations  Vertical
# 21      HCSEG/DOE  Vertical
# 22     P Stations  Vertical
# 23      HCSEG/DOE  Vertical
# 24      NOAA/STIL   Oblique
# 25           NOAA   Oblique
# 26           NOAA   Oblique
# 27      NOAA/STIL  Vertical
# 28           NOAA  Vertical
# 29             KC   Oblique
# 30             KC  Vertical
# 31             KC   Oblique
# 32             KC   Oblique
# 33             KC  Vertical
# 34            TUL   Oblique
# 35            TUL   Oblique
# 36            TUL   Oblique
# 37            TUL  Vertical
# 38             KC  Vertical
# 39      NOAA/STIL   Oblique
# 40            NIT   Oblique
# 41           NOAA   Oblique
# 42      NOAA/STIL   Oblique
# 43           NOAA   Oblique
# 44      NOAA/STIL  Vertical
# 45     P Stations  Vertical
# 46           NOAA  Vertical
# 47            NIT   Oblique
# 48            NIT   Oblique
# 49            NIT   Oblique
# 50            NIT   Oblique
# 51            NIT  Vertical
# 52      PGST/WDFW   Oblique
# 53      PGST/WDFW   Oblique
# 54      PGST/WDFW   Oblique
# 55      PGST/WDFW  Vertical
# 56            KWT   Oblique
# 57            KWT  Vertical
# 58            KWT   Oblique
# 59            KWT  Vertical

# %%
# lhs_df = pd.DataFrame(source_df['lhs'].value_counts()).sort_index()

# %% [markdown]
# ## Fix time issues
#
# - Assign correct timezone (PDT, not UTC)
# - Fill in missing `time_start`, by `sample_code`

# %%
# source_df.loc[source_df.sample_code == "20130903UNDm1_335"].head(3)

# %% [markdown]
# Create (replace) the `time` column based on `date`, `time_start`, my custom `pdt` timezone, and `strftime`

# %%
source_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46276 entries, 0 to 46275
# Data columns (total 42 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   BugSampleID                        46276 non-null  int64
#  1   Project                            46276 non-null  object
#  2   Sample Code                        46276 non-null  object
#  3   Sampling Group                     46276 non-null  object
#  4   Station                            46276 non-null  object
#  5   Site                               46276 non-null  object
#  6   Site Name                          46276 non-null  object
#  7   Basin                              46276 non-null  object
#  8   Sub Basin                          46276 non-null  object
#  9   Latitude                           46276 non-null  float64
#  10  Longitude                          46276 non-null  float64
#  11  Date Category                      46191 non-null  datetime64[ns]
#  12  Sample Date                        46276 non-null  object
#  13  Sample Year                        46276 non-null  int64
#  14  Sample Month                       46276 non-null  object
#  15  Season                             46276 non-null  object
#  16  Rep                                46276 non-null  object
#  17  Sample Time                        46276 non-null  object
#  18  Day_Night                          46276 non-null  object
#  19  Tow Type                           46276 non-null  object
#  20  Mesh Size                          46276 non-null  int64
#  21  Diameter (cm)                      46276 non-null  int64
#  22  Station Depth (m)                  45967 non-null  float64
#  23  Sensor Depth (m)                   9038 non-null   float64
#  24  Max Tow Depth (m)                  46276 non-null  int64
#  25  Min Tow Depth (m)                  45883 non-null  float64
#  26  Avg Station Depth (m)              46276 non-null  float64
#  27  Target Depth (m)                   46276 non-null  int64
#  28  Flowmeter                          46125 non-null  object
#  29  Flow meter (revs)                  46276 non-null  float64
#  30  Vol Filtered (m3)                  46276 non-null  float64
#  31  Broad Group                        46276 non-null  object
#  32  Mid-Level Group                    46276 non-null  object
#  33  Genus species                      46276 non-null  object
#  34  Life History Stage                 46276 non-null  object
#  35  ID Code                            46276 non-null  object
#  36  Density (#/m3)                     45904 non-null  float64
#  37  Final Carbon (mg/m3)               46276 non-null  float64
#  38  Species Size Category Aggregation  46276 non-null  object
#  39  Size Category Aggregation          46276 non-null  object
#  40  Prey Field Index                   46276 non-null  object
#  41  Collection Confidence              46276 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(6), object(25)
# memory usage: 14.8+ MB

# %%
source_df[['BugSampleID', 'Sample Code', 'Sample Date', 'Sample Time']].head()
# Out:
#    BugSampleID        Sample Code          Sample Date Sample Time
# 0       181590  010322KSBP01D0815  2022-01-03 00:00:00    08:15:00
# 1       181593  010322KSBP01D0815  2022-01-03 00:00:00    08:15:00
# 2       181594  010322KSBP01D0815  2022-01-03 00:00:00    08:15:00
# 3       181604  010422LSNT01D1323  2022-01-04 00:00:00    13:23:00
# 4       181609  010422LSNT01D1323  2022-01-04 00:00:00    13:23:00

# %% [markdown]
# - **TODO:** Enable a timezone generator so the correct UTC offset (-7 or -8) is applied. Currently, it's hardwired to a constant value
# - `Sample Date` includes a string for time ("00:00:00") that must be removed first.
# - Will parse for seconds, but they're all 0; the resolution is minutes

# %%
pdt = timezone(timedelta(hours=-7), "PDT")
source_df["time"] = pd.to_datetime(
    source_df["Sample Date"].str.split(' ').str[0] + source_df["Sample Time"], 
    format="%Y-%m-%d%H:%M:%S"
).dt.tz_localize(pdt)

# %% [markdown]
# No errors with datetime conversion!

# %%
source_df.head()
# Out:
#    BugSampleID Project        Sample Code Sampling Group  Station    Site  \
# 0       181590   SSMSP  010322KSBP01D0815             KC  KSBP01D  KSBP01
# 1       181593   SSMSP  010322KSBP01D0815             KC  KSBP01D  KSBP01
# 2       181594   SSMSP  010322KSBP01D0815             KC  KSBP01D  KSBP01
# 3       181604   SSMSP  010422LSNT01D1323             KC  LSNT01D  LSNT01
# 4       181609   SSMSP  010422LSNT01D1323             KC  LSNT01D  LSNT01
#
#          Site Name          Basin        Sub Basin  Latitude  ...  \
# 0  Point Jefferson  Central Basin  N Central Basin  47.74396  ...
# 1  Point Jefferson  Central Basin  N Central Basin  47.74396  ...
# 2  Point Jefferson  Central Basin  N Central Basin  47.74396  ...
# 3   Point Williams  Central Basin  N Central Basin  47.53333  ...
# 4   Point Williams  Central Basin  N Central Basin  47.53333  ...
#
#             Genus species Life History Stage      ID Code  Density (#/m3)  \
# 0  CYPHOCARIS CHALLENGERI            Unknown  6169341101C        0.017520
# 1              HYPERIIDEA            Unknown        6170C       80.940469
# 2       THEMISTO PACIFICA            Unknown  6170011003C        8.409399
# 3  CYPHOCARIS CHALLENGERI            Unknown  6169341101C        0.068919
# 4       THEMISTO PACIFICA            Unknown  6170011003C       14.473009
#
#   Final Carbon (mg/m3) Species Size Category Aggregation  \
# 0             0.001591                          Amphipod
# 1             1.606125                          Amphipod
# 2             0.715335                          Amphipod
# 3             0.014498                          Amphipod
# 4             0.166785                          Amphipod
#
#   Size Category Aggregation Prey Field Index Collection Confidence  \
# 0                  Amphipod            Other                  High
# 1                  Amphipod         Hyperiid                  High
# 2                  Amphipod         Hyperiid                  High
# 3                  Amphipod            Other                  high
# 4                  Amphipod         Hyperiid                  high
#
#                        time
# 0 2022-01-03 08:15:00-07:00
# 1 2022-01-03 08:15:00-07:00
# 2 2022-01-03 08:15:00-07:00
# 3 2022-01-04 13:23:00-07:00
# 4 2022-01-04 13:23:00-07:00
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Replace incorrect `life_history_stage` values

# %% [markdown]
# - Simple replacement of "F1_0;_Furcilia_1_0_legs" entry with "F10;_Furcilia_10". Use pandas `replace` on the column
# - EUPHAUSIA_PACIFICA and THYSANOESSA in `species` column: replace `life_history_stage` based on combined `species` and `life_history_stage` entries
#   > Calyptopis 1-3 life_history_stage codes. For Euphasia Pacifica, calyptopis life stages are typically coded in life_history_stage as "Cal1;_Calyptopis_1", "Cal2;_Calyptopis_2" and "Cal3;_Calyptopis_3" (same for thysanoessa). But there are a few Euphasia records that include the following codes: "1;_CI", "2;_CII", "3;_CIII". These are the same life_history_stage codes used for copepods, copepodites C1 - C3. My guess is that they're miscoded and should be calyptopis 1-3. Can you confirm?
#
#   Yes, these are miscoded ("1, CI" should be "Cal1, calyptopis 1," and so on).

# %%
source_df["life_history_stage"].replace({"F1_0;_Furcilia_1_0_legs": "F10;_Furcilia_10"}, inplace=True)

# %%
sel_species = source_df["species"].isin(["EUPHAUSIA_PACIFICA", "THYSANOESSA"])

krill_bad_life_history_stages = {
    "1;_CI": "Cal1;_Calyptopis_1", 
    "2;_CII": "Cal2;_Calyptopis_2",
    "3;_CIII": "Cal3;_Calyptopis_3",
}

# %%
for old_lhs,new_lhs in krill_bad_life_history_stages.items():
    source_df.loc[sel_species & source_df["life_history_stage"].str.startswith(old_lhs), "life_history_stage"] = new_lhs

# %% [markdown]
# ### Parse `life_history_stage`

# %% [markdown]
# #### Parse into `lhs_0` and `lhs_1` tokens

# %%
source_df[['lhs_0', 'lhs_1']] = pd.DataFrame(
    source_df['life_history_stage'].str.split(';_').to_list(), 
    index=source_df.index
)

# %%
source_df[['life_history_stage', 'lhs_0', 'lhs_1']].value_counts(dropna=False, sort=False).sort_index(ascending=True)
# Out:
# life_history_stage  lhs_0             lhs_1
# 1;_CI               1                 CI               120
# 2;_CII              2                 CII              176
# 3;_CIII             3                 CIII             272
# 4;_CIV              4                 CIV              492
# 5;_CV               5                 CV               611
# Adult               Adult             NaN              194
# Bract               Bract             NaN                6
# Cal1;_Calyptopis_1  Cal1              Calyptopis_1      49
# Cal2;_Calyptopis_2  Cal2              Calyptopis_2      34
# Cal3;_Calyptopis_3  Cal3              Calyptopis_3      42
# Copepodite          Copepodite        NaN              265
# Cyphonaut           Cyphonaut         NaN               81
# Cyprid_larva        Cyprid_larva      NaN               36
# Egg                 Egg               NaN               91
# Eudoxid             Eudoxid           NaN                5
# F10;_Furcilia_10    F10               Furcilia_10        3
# F1;_Furcilia_1      F1                Furcilia_1        76
# F2;_Furcilia_2      F2                Furcilia_2        66
# F3;_Furcilia_3      F3                Furcilia_3        57
# F4;_Furcilia_4      F4                Furcilia_4        30
# F5;_Furcilia_5      F5                Furcilia_5        10
# F6;_Furcilia_6      F6                Furcilia_6        24
# F7;_Furcilia_7      F7                Furcilia_7        24
# F9;_Furcilia_9      F9                Furcilia_9         1
# Female;_Adult       Female            Adult            878
# Gonophore           Gonophore         NaN                5
# Juvenile            Juvenile          NaN              147
# Larva               Larva             NaN              119
# Male;_Adult         Male              Adult            675
# Medusa              Medusa            NaN              214
# Megalopa            Megalopa          NaN               37
# Metanauplius        Metanauplius      NaN               61
# Mysis_larva         Mysis_larva       NaN                9
# N1;_Nauplius_1      N1                Nauplius_1        28
# N2;_Nauplius_2      N2                Nauplius_2        48
# N6;_Nauplius_6      N6                Nauplius_6         3
# Nauplii             Nauplii           NaN               95
# Nectophore          Nectophore        NaN               15
# Planula_larvae      Planula_larvae    NaN                3
# Pluteus_larva       Pluteus_larva     NaN               17
# Polyp               Polyp             NaN                2
# Trocophore_larva    Trocophore_larva  NaN               13
# Unknown             Unknown           NaN             1124
# Veliger             Veliger           NaN              136
# Z1;_Zoea_I          Z1                Zoea_I           162
# Z2;_Zoea_II         Z2                Zoea_II          113
# Z3;_Zoea_III        Z3                Zoea_III          92
# Z4;_Zoea_IV         Z4                Zoea_IV           74
# Z5;_Zoea_V          Z5                Zoea_V            24
# Zoea                Zoea              NaN               25
# dtype: int64

# %% [markdown]
# ### Examine original issues with incorrect entries
#
# **NOTE:** The statements below will show the original issues only when run with the `lhs_0` and `lhs_1` columns parsed from the *original, unaltered* `life_history_stage` entries. I've commented them out for that reason.

# %% [markdown]
# Examine use of CI-V life stages (Copepodites?) with EUPHAUSIA_PACIFICA krill. Note that only CI-III are used with krill, and only a small subset of the totals (9, 9 & 6, respectively)

# %%
# source_df[source_df.species == 'EUPHAUSIA_PACIFICA'][['lhs_0', 'lhs_1']].value_counts(dropna=False).sort_index(ascending=True)

# %% [markdown]
# Confirm that 'Cal1', 'Cal2', 'Cal3' are only used with krill

# %%
# pd.DataFrame(
#     source_df[source_df.lhs_0.isin(['Cal1', 'Cal2', 'Cal3'])]
#     [['lhs_0', 'lhs_1', 'species']]
#     .value_counts(dropna=False)
#     .sort_index(ascending=True)
# ).head(60)

# %%
# pd.DataFrame(
#     source_df.lhs_0.isin(['1', '2', '3', '4', '5'])
#     [['lhs_0', 'lhs_1', 'species']]
#     .value_counts(dropna=False)
#     .sort_index(ascending=True)
# ).head(60)

# %% [markdown]
# ## Move the taxonomy replacements here??
#
# No, b/c the taxonomy notebook also does a lot of other taxonomy querying and mappings, so it's best to keep it all there.

# %% [markdown]
# ## Package versions

# %%
print(
    f"{datetime.utcnow()} +00:00\n"
    f"pandas: {pd.__version__}, geopandas: {gpd.__version__}"
)
# Out:
# 2023-11-01 02:47:27.815453 +00:00
# pandas: 1.5.3, geopandas: 0.12.2
