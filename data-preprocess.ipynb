# %% [markdown]
# # Data pre-processing. PSZMP
#
# PSZMP dataset.
#
# 2/10-9,6,4, 1/31/2024

# %%
from datetime import datetime
import json
from pathlib import Path

import numpy as np
import pandas as pd
import geopandas as gpd

from data_preprocess import read_and_parse_sourcedata

# %% [markdown]
# ## Read the data

# %%
data_pth = Path(".")

# %% [markdown]
# Set to `True` when debugging. `csv` ﬁles will not be exported when `debug_no_csvexport = True`

# %%
debug_no_csvexport = False

# %% [markdown]
# ## Process JSON file containing common mappings and strings

# %%
with open(data_pth / 'common_mappings.json') as f:
    common_mappings = json.load(f)

# %%
DatasetCode = common_mappings['datasetcode']
cruises = common_mappings['cruises']
stations = common_mappings['stations']
net_tow = common_mappings['net_tow']

iso8601_format = common_mappings['iso8601_format']
CRS = common_mappings['CRS']

# %% [markdown]
# ## Pre-process data from csv for Event table

# %% [markdown]
# ### Read the pre-processed csv file

# %% [markdown]
# `usecols` defines the columns that will be kept and the order in which they'll be organized

# %%
# From the Hood Canal dataset
# usecols = [
#     'sample_code', 'mesh_size', 'FWC_DS', 
#     'station', 'latitude', 'longitude', 
#     'date', 'time_start', 'time', 'day_night', 
#     'depth_min', 'depth_max',
#     'net_code', 'extra_sample_token'
# ]

usecols = [
    'Sample Code', 
    'Station', 'Latitude', 'Longitude', 'Site Name', 'Basin', 'Sampling Group',
    'Sample Date', 'Sample Time', 'Day_Night', 'time',
    'Min Tow Depth (m)', 'Max Tow Depth (m)', 'Station Depth (m)',
    'Mesh Size', 'Tow Type', 
]

# eventsource_df = read_and_parse_sourcedata(test_n_rows=1000)[usecols]
eventsource_df = read_and_parse_sourcedata()[usecols]

# TODO: Rename more columns, if needed
eventsource_df.rename(
    columns={
        'Sample Code':'sample_code',
        'Station':'station',
        'Latitude':'latitude',
        'Longitude':'longitude',
        'Min Tow Depth (m)':'depth_min', 
        'Max Tow Depth (m)':'depth_max', 
        'Mesh Size': 'mesh_size',
    },
    inplace=True
)

# %%
len(eventsource_df)
# Out:
# 153825

# %%
eventsource_df.head()
# Out:
#       sample_code station  latitude  longitude     Site Name           Basin  \
# 0  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 1  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 2  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 3  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
# 4  010218ELIV1151    ELIV  48.63795  -122.5694  Eliza Island  Bellingham Bay
#
#   Sampling Group          Sample Date Sample Time Day_Night  \
# 0            LUM  2018-01-02 00:00:00    11:51:00         D
# 1            LUM  2018-01-02 00:00:00    11:51:00         D
# 2            LUM  2018-01-02 00:00:00    11:51:00         D
# 3            LUM  2018-01-02 00:00:00    11:51:00         D
# 4            LUM  2018-01-02 00:00:00    11:51:00         D
#
#                        time  depth_min  depth_max  Station Depth (m)  \
# 0 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 1 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 2 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 3 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 4 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
#
#    mesh_size  Tow Type
# 0        200  Vertical
# 1        200  Vertical
# 2        200  Vertical
# 3        200  Vertical
# 4        200  Vertical

# %% [markdown]
# ### Remove duplicates
#
# Will return only unique samples, where one row = one sample.

# %%
eventsource_df = eventsource_df.drop_duplicates().sort_values(by='sample_code').reset_index(drop=True)
len(eventsource_df)
# Out:
# 3567

# %% [markdown]
# - There are 51 unique stations
# - Adding 'Tow Type' didn't lead to duplication of stations. ie, each station has only one tow type.
# - Adding 'Station Depth (m)' did lead to huge duplication
# - Darn, adding 'Sampling Group' led to some duplication (60 records instead of 51). ie, some stations were visited by more than one 'Sampling Group'

# %%
stations_cols = ['station', 'latitude', 'longitude', 'Site Name', 'Basin', 'Sampling Group', 'Tow Type']

# %%
stations_unique_df = eventsource_df[stations_cols].drop_duplicates().sort_values(by='station').reset_index(drop=True)
len(stations_unique_df)
# Out:
# 60

# %%
sorted(stations_unique_df['Sampling Group'].unique())
# Out:
# ['HCSEG/DOE',
#  'KC',
#  'KWT',
#  'LUM',
#  'NIT',
#  'NOAA',
#  'NOAA/STIL',
#  'P Stations',
#  'PGST/WDFW',
#  'TUL']

# %%
stations_unique_df['Sampling Group'].value_counts()
# Out:
# NIT           10
# PGST/WDFW      8
# TUL            8
# KWT            8
# NOAA           6
# KC             6
# NOAA/STIL      5
# LUM            4
# P Stations     3
# HCSEG/DOE      2
# Name: Sampling Group, dtype: int64

# %%
stations_unique_df.head(60)
# Out:
#     station  latitude  longitude                Site Name            Basin  \
# 0      ADID  48.00274  -122.6374          Admiralty Inlet  Admiralty Inlet
# 1      ADIM  47.99915  -122.6664          Admiralty Inlet  Admiralty Inlet
# 2      ADIS  47.99063  -122.6872          Admiralty Inlet  Admiralty Inlet
# 3      ADIV  48.00273  -122.6360          Admiralty Inlet  Admiralty Inlet
# 4      CAMD  48.06646  -122.3956              Camano Head    Whidbey Basin
# 5      CAMM  48.06536  -122.3905              Camano Head    Whidbey Basin
# 6      CAMS  48.06469  -122.3886              Camano Head    Whidbey Basin
# 7      CAMV  48.05901  -122.3873              Camano Head    Whidbey Basin
# 8     COW1S  48.68448  -123.0400                  Cowlitz         San Juan
# 9     COW2D  48.68303  -123.0412                  Cowlitz         San Juan
# 10   COW2D2  48.67437  -123.0481                  Cowlitz         San Juan
# 11   COW3V2  48.67437  -123.0481                  Cowlitz         San Juan
# 12    DANAD  47.17997  -122.8318             Dana Passage      South Sound
# 13    DANAM  47.17678  -122.8352             Dana Passage      South Sound
# 14    DANAS  47.17593  -122.8355             Dana Passage      South Sound
# 15    DANAV  47.18327  -122.8307             Dana Passage      South Sound
# 16     ELID  48.63368  -122.5890             Eliza Island   Bellingham Bay
# 17     ELIM  48.64060  -122.5896             Eliza Island   Bellingham Bay
# 18     ELIS  48.64352  -122.5886             Eliza Island   Bellingham Bay
# 19     ELIV  48.63795  -122.5694             Eliza Island   Bellingham Bay
# 20  HCB003V  47.53787  -123.0096                    Eldon       Hood Canal
# 21  HCB003V  47.53787  -123.0096                    Eldon       Hood Canal
# 22  HCB004V  47.35620  -123.0249            Sisters Point       Hood Canal
# 23  HCB004V  47.35620  -123.0249            Sisters Point       Hood Canal
# 24    HOPED  48.41155  -122.5657        North Hope Island    Whidbey Basin
# 25    HOPED  48.41155  -122.5657        North Hope Island    Whidbey Basin
# 26    HOPES  48.40463  -122.5560        North Hope Island    Whidbey Basin
# 27    HOPEV  48.40622  -122.5783        North Hope Island    Whidbey Basin
# 28    HOPEV  48.40622  -122.5783        North Hope Island    Whidbey Basin
# 29  KSBP01D  47.74396  -122.4282          Point Jefferson    Central Basin
# 30  KSBP01V  47.74396  -122.4282          Point Jefferson    Central Basin
# 31  LSNT01D  47.53333  -122.4333           Point Williams    Central Basin
# 32  LSNT01S  47.54225  -122.4012           Point Williams    Central Basin
# 33  LSNT01V  47.53333  -122.4333           Point Williams    Central Basin
# 34     MUKD  47.95922  -122.2906                 Mukilteo    Whidbey Basin
# 35     MUKM  47.95711  -122.2873                 Mukilteo    Whidbey Basin
# 36     MUKS  47.95509  -122.2874                 Mukilteo    Whidbey Basin
# 37     MUKV  47.97166  -122.3222                 Mukilteo    Whidbey Basin
# 38  NSEX01V  47.35862  -122.3871             East Passage    Central Basin
# 39    SARAD  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 40    SARAD  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 41    SARAD  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 42    SARAS  48.27363  -122.5529   North Saratoga Passage    Whidbey Basin
# 43    SARAS  48.27363  -122.5529   North Saratoga Passage    Whidbey Basin
# 44    SARAV  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 45    SARAV  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 46    SARAV  48.25673  -122.5442   North Saratoga Passage    Whidbey Basin
# 47    SKETD  47.14032  -122.6377  South Ketron/Solo Point      South Sound
# 48   SKETD2  47.13932  -122.6490  South Ketron/Solo Point      South Sound
# 49    SKETM  47.13892  -122.6367  South Ketron/Solo Point      South Sound
# 50    SKETS  47.13843  -122.6354  South Ketron/Solo Point      South Sound
# 51    SKETV  47.15243  -122.6586  South Ketron/Solo Point      South Sound
# 52     TDBD  47.78343  -122.7334            Thorndyke Bay       Hood Canal
# 53     TDBM  47.79400  -122.7348            Thorndyke Bay       Hood Canal
# 54     TDBS  47.79868  -122.7334            Thorndyke Bay       Hood Canal
# 55     TDBV  47.78297  -122.7330            Thorndyke Bay       Hood Canal
# 56    WAT1S  48.43457  -122.8037             Watmough Bay         San Juan
# 57    WAT1V  48.43457  -122.8037             Watmough Bay         San Juan
# 58    WAT2D  48.43699  -122.7961             Watmough Bay         San Juan
# 59    WAT3V  48.43548  -122.7929             Watmough Bay         San Juan
#
#    Sampling Group  Tow Type
# 0       PGST/WDFW   Oblique
# 1       PGST/WDFW   Oblique
# 2       PGST/WDFW   Oblique
# 3       PGST/WDFW  Vertical
# 4             TUL   Oblique
# 5             TUL   Oblique
# 6             TUL   Oblique
# 7             TUL  Vertical
# 8             KWT   Oblique
# 9             KWT   Oblique
# 10            KWT   Oblique
# 11            KWT  Vertical
# 12            NIT   Oblique
# 13            NIT   Oblique
# 14            NIT   Oblique
# 15            NIT  Vertical
# 16            LUM   Oblique
# 17            LUM   Oblique
# 18            LUM   Oblique
# 19            LUM  Vertical
# 20     P Stations  Vertical
# 21      HCSEG/DOE  Vertical
# 22     P Stations  Vertical
# 23      HCSEG/DOE  Vertical
# 24      NOAA/STIL   Oblique
# 25           NOAA   Oblique
# 26           NOAA   Oblique
# 27      NOAA/STIL  Vertical
# 28           NOAA  Vertical
# 29             KC   Oblique
# 30             KC  Vertical
# 31             KC   Oblique
# 32             KC   Oblique
# 33             KC  Vertical
# 34            TUL   Oblique
# 35            TUL   Oblique
# 36            TUL   Oblique
# 37            TUL  Vertical
# 38             KC  Vertical
# 39      NOAA/STIL   Oblique
# 40            NIT   Oblique
# 41           NOAA   Oblique
# 42      NOAA/STIL   Oblique
# 43           NOAA   Oblique
# 44      NOAA/STIL  Vertical
# 45     P Stations  Vertical
# 46           NOAA  Vertical
# 47            NIT   Oblique
# 48            NIT   Oblique
# 49            NIT   Oblique
# 50            NIT   Oblique
# 51            NIT  Vertical
# 52      PGST/WDFW   Oblique
# 53      PGST/WDFW   Oblique
# 54      PGST/WDFW   Oblique
# 55      PGST/WDFW  Vertical
# 56            KWT   Oblique
# 57            KWT  Vertical
# 58            KWT   Oblique
# 59            KWT  Vertical

# %% [markdown]
# Generate unique station records that also include `time`. That is, each unique station visit.

# %%
stationvisits_unique_df = (
    eventsource_df[stations_cols + ['time']].drop_duplicates()
    .sort_values(by='station').reset_index(drop=True)
)
len(stationvisits_unique_df)
# Out:
# 3567

# %% [markdown]
# Same number of records as `eventsource_df`! Note that `stationvisit_df` in the Event notebook is just slightly smaller, with 3551 records. That DF is based on a groupby where time and depth are summarized to their min & max.

# %%
len(stationvisits_unique_df) == len(eventsource_df)
# Out:
# True

# %% [markdown]
# ### Come up with a "cruise code" based on Sampling Group and a date or counter
#
# - Ideally the date string would be yyyymm
# - Challenge is if for a given outing, the Sampling Group went out over a period of that spanned two months (eg, 5/31 & 6/1). Then the scheme would would break them up into separate outings
# - Start by just testing the yyyymm approach, then examine the results to decide next steps
# - But maybe it's ok not to try to aggregate every single unique outing into a common cruise code! Or it's something we could revisit later if we think it's worthwhile.

# %%
eventsource_df['date_yyyymm'] = eventsource_df['time'].apply(lambda dt: dt.strftime("%Y%m"))
# eventsource_df['cruise_code'] = eventsource_df['date_yyyymm'].apply(lambda s: cruises[s])
eventsource_df['cruise_code'] = (
    eventsource_df['date_yyyymm'] + "_" + eventsource_df['Sampling Group']
)

# %%
len(eventsource_df['cruise_code'].unique())
# Out:
# 638

# %%
eventsource_df.head(5)
# Out:
#          sample_code  station  latitude  longitude        Site Name  \
# 0     010218ELIV1151     ELIV  48.63795  -122.5694     Eliza Island
# 1  010322KSBP01D0815  KSBP01D  47.74396  -122.4282  Point Jefferson
# 2  010422LSNT01D1323  LSNT01D  47.53333  -122.4333   Point Williams
# 3  010422LSNT01V1305  LSNT01V  47.53333  -122.4333   Point Williams
# 4  010422NSEX01V1049  NSEX01V  47.35862  -122.3871     East Passage
#
#             Basin Sampling Group          Sample Date Sample Time Day_Night  \
# 0  Bellingham Bay            LUM  2018-01-02 00:00:00    11:51:00         D
# 1   Central Basin             KC  2022-01-03 00:00:00    08:15:00         D
# 2   Central Basin             KC  2022-01-04 00:00:00    13:23:00         D
# 3   Central Basin             KC  2022-01-04 00:00:00    13:05:00         D
# 4   Central Basin             KC  2022-01-04 00:00:00    10:49:00         D
#
#                        time  depth_min  depth_max  Station Depth (m)  \
# 0 2018-01-02 11:51:00-07:00        0.0      110.0              120.7
# 1 2022-01-03 08:15:00-07:00       22.0        0.0              275.0
# 2 2022-01-04 13:23:00-07:00       38.0        0.0              210.0
# 3 2022-01-04 13:05:00-07:00        0.0      200.0              210.0
# 4 2022-01-04 10:49:00-07:00        0.0      170.0              180.0
#
#    mesh_size  Tow Type date_yyyymm cruise_code
# 0        200  Vertical      201801  201801_LUM
# 1        335   Oblique      202201   202201_KC
# 2        335   Oblique      202201   202201_KC
# 3        200  Vertical      202201   202201_KC
# 4        200  Vertical      202201   202201_KC

# %%
df = (
    pd.DataFrame(eventsource_df['cruise_code'].value_counts())
    .reset_index()
    .rename(columns={'index':'cruise_code', 'cruise_code':'count'})
    .sort_values(by='cruise_code')
).to_csv("./cruise_codes-fromSGandYYYYMM.csv", index=False)

# %% [markdown]
# Let's see what happens if we include the day (YYYYMMDD) in the cruise code

# %%
len(eventsource_df['time'].apply(lambda dt: dt.strftime("%Y%m%d")).unique())
# Out:
# 1045

# %%
eventsource_df['date_yyyymmdd'] = eventsource_df['time'].apply(lambda dt: dt.strftime("%Y%m%d"))
# eventsource_df['cruise_code'] = eventsource_df['date_yyyymm'].apply(lambda s: cruises[s])
eventsource_df['cruise_code_yyyymmdd'] = (
    eventsource_df['date_yyyymmdd'] + "_" + eventsource_df['Sampling Group']
)

# %%
len(eventsource_df['cruise_code_yyyymmdd'].unique())
# Out:
# 1332

# %%
cruisecode_yyyymmdd_unique_df = (
    # eventsource_df[['cruise_code'] + stations_cols].drop_duplicates()
    # .sort_values(by=['cruise_code', 'station']).reset_index(drop=True)
    eventsource_df[['cruise_code', 'cruise_code_yyyymmdd'] + stations_cols].drop_duplicates()
    .sort_values(by=['cruise_code_yyyymmdd', 'station']).reset_index(drop=True)
)
len(cruisecode_yyyymmdd_unique_df)
# Out:
# 3567

# %%
cruisecode_yyyymmdd_unique_df.tail(20)
# Out:
#            cruise_code cruise_code_yyyymmdd  station  latitude  longitude  \
# 3547        202211_KWT         20221113_KWT    WAT1V  48.43457  -122.8037
# 3548         202211_KC          20221114_KC  KSBP01D  47.74396  -122.4282
# 3549         202211_KC          20221114_KC  KSBP01V  47.74396  -122.4282
# 3550         202211_KC          20221115_KC  LSNT01D  47.53333  -122.4333
# 3551         202211_KC          20221115_KC  LSNT01V  47.53333  -122.4333
# 3552         202211_KC          20221115_KC  NSEX01V  47.35862  -122.3871
# 3553         202212_KC          20221205_KC  KSBP01D  47.74396  -122.4282
# 3554         202212_KC          20221205_KC  KSBP01V  47.74396  -122.4282
# 3555         202212_KC          20221206_KC  LSNT01D  47.53333  -122.4333
# 3556         202212_KC          20221206_KC  LSNT01V  47.53333  -122.4333
# 3557         202212_KC          20221206_KC  NSEX01V  47.35862  -122.3871
# 3558        202212_KWT         20221212_KWT   COW3V2  48.67437  -123.0481
# 3559        202212_KWT         20221212_KWT    WAT1V  48.43457  -122.8037
# 3560        202212_TUL         20221212_TUL     CAMV  48.05901  -122.3873
# 3561        202212_TUL         20221212_TUL     MUKV  47.97166  -122.3222
# 3562  202212_HCSEG/DOE   20221214_HCSEG/DOE  HCB003V  47.53787  -123.0096
# 3563  202212_HCSEG/DOE   20221214_HCSEG/DOE  HCB004V  47.35620  -123.0249
# 3564  202212_NOAA/STIL   20221215_NOAA/STIL    SARAV  48.25673  -122.5442
# 3565  202212_PGST/WDFW   20221219_PGST/WDFW     ADIV  48.00273  -122.6360
# 3566  202212_PGST/WDFW   20221219_PGST/WDFW     TDBV  47.78297  -122.7330
#
#                    Site Name            Basin Sampling Group  Tow Type
# 3547            Watmough Bay         San Juan            KWT  Vertical
# 3548         Point Jefferson    Central Basin             KC   Oblique
# 3549         Point Jefferson    Central Basin             KC  Vertical
# 3550          Point Williams    Central Basin             KC   Oblique
# 3551          Point Williams    Central Basin             KC  Vertical
# 3552            East Passage    Central Basin             KC  Vertical
# 3553         Point Jefferson    Central Basin             KC   Oblique
# 3554         Point Jefferson    Central Basin             KC  Vertical
# 3555          Point Williams    Central Basin             KC   Oblique
# 3556          Point Williams    Central Basin             KC  Vertical
# 3557            East Passage    Central Basin             KC  Vertical
# 3558                 Cowlitz         San Juan            KWT  Vertical
# 3559            Watmough Bay         San Juan            KWT  Vertical
# 3560             Camano Head    Whidbey Basin            TUL  Vertical
# 3561                Mukilteo    Whidbey Basin            TUL  Vertical
# 3562                   Eldon       Hood Canal      HCSEG/DOE  Vertical
# 3563           Sisters Point       Hood Canal      HCSEG/DOE  Vertical
# 3564  North Saratoga Passage    Whidbey Basin      NOAA/STIL  Vertical
# 3565         Admiralty Inlet  Admiralty Inlet      PGST/WDFW  Vertical
# 3566           Thorndyke Bay       Hood Canal      PGST/WDFW  Vertical

# %%
len(cruisecode_yyyymmdd_unique_df['cruise_code_yyyymmdd'].unique())
# Out:
# 1332

# %%
cruisecode_yyyymmdd_unique_df['cruise_code_yyyymmdd'].value_counts()
# Out:
# 20151021_PGST/WDFW    8
# 20140619_NIT          8
# 20140904_NIT          8
# 20140624_NIT          8
# 20150608_TUL          8
#                      ..
# 20180824_NOAA         1
# 20211216_LUM          1
# 20160330_NIT          1
# 20220103_KC           1
# 20181212_NIT          1
# Name: cruise_code_yyyymmdd, Length: 1332, dtype: int64

# %% [markdown]
# ## Mesh size and tow type
#
# Only two sets occur: Vertical+200um and Oblique+335um. That makes it easy to handle! Is it the same as the Hood Canal dataset?

# %%
eventsource_df[['Tow Type', 'mesh_size']].value_counts()
# Out:
# Tow Type  mesh_size
# Vertical  200          1802
# Oblique   335          1765
# dtype: int64

# %% [markdown]
# ## Day vs Night sampling

# %%
eventsource_df['Day_Night'].value_counts()
# Out:
# D    3331
# N     220
# Name: Day_Night, dtype: int64

# %% [markdown]
# ## Package versions

# %%
print(
    f"{datetime.utcnow()} +00:00\n"
    f"pandas: {pd.__version__}, geopandas: {gpd.__version__}"
)
# Out:
# 2024-02-10 21:23:41.080205 +00:00
# pandas: 1.5.3, geopandas: 0.12.2
